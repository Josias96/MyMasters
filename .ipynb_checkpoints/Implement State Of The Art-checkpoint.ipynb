# %% [markdown]
# # State Of The Art UNET
# ## JA Engelbrecht

# %%
from matplotlib import rc
from jupyterthemes import jtplot
from skimage.util import montage as montage2d
import UNets.MyImplementation.UNET_Adv7 as UNet

from MyFunctions.learningRateFunction import LRFinder
from MyFunctions.CreatePaths import CreatePaths
from MyFunctions.LoadImages import LoadImages
from MyFunctions.RunModels import RunModels

from CLR.clr_callback import *

import SimpleITK as sitk
import tensorflow as tf
import pandas as pd
import numpy as np
import importlib
import os

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split

############ Plot Images/Graphs Functions ############

from matplotlib.colors import LinearSegmentedColormap
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import matplotlib as mpl

cmap = LinearSegmentedColormap.from_list('mycmap', ['black', 'orange', 'red'])


rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)
mpl.rcParams.update({'font.size': 12})


def set_size(width='thesis', fraction=1, subplots=(1, 1)):
    """Set figure dimensions to avoid scaling in LaTeX.

    Parameters
    ----------
    width: float or string
            Document width in points, or string of predined document type
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy
    subplots: array-like, optional
            The number of rows and columns of subplots.
    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    if width == 'thesis':
        width_pt = 398
    else:
        width_pt = width

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)


def showCTImage(IMG, SIZE):
    plt.figure(figsize=(SIZE, SIZE))
    plt.imshow(IMG, alpha=1, cmap='gray')
    plt.axis('off')
    plt.show()


def showCTMontage(IMG, SIZE, SaveFig=False, save_fig_name=""):
    plt.figure(figsize=(SIZE, SIZE))
    plt.imshow(montage2d(IMG), alpha=1, cmap='gray')
    plt.axis('off')
    plt.show()
    if SaveFig:
        save_fig_path = os.path.join(os.curdir, "SavedFigures")
        plt.savefig(os.path.join(save_fig_path,
                                 save_fig_name+".pdf"), bbox_inches='tight')


def showCTMontageOverlay(IMG1, IMG2, SIZE=15, SaveFig=False, save_fig_name=""):
    fig, ax = plt.subplots(figsize=(SIZE, SIZE))
    try:
        ax.imshow(montage2d(IMG1), alpha=1, cmap='gray')
    except:
        print("Error: Img 1")
    try:
        ax.imshow(montage2d(IMG2, fill=0), alpha=0.5,
                  cmap=cmap, interpolation='none')
    except:
        print("Error: Img 2")
    plt.axis('off')

    if SaveFig:
        save_fig_path = os.path.join(os.curdir, "SavedFigures")
        plt.savefig(os.path.join(save_fig_path,
                                 save_fig_name+".pdf"), bbox_inches='tight')
    plt.show()
######################################################

# %% [markdown]
# # Set Variables

# %%
# Change Class Variable below for different paths e.g. CT/PET
path = CreatePaths(DeviceFlag="PC", ScanTypeFlag="CT", TrainTestFlag="Train")

#DATA_PATH = "D://Masters_Repo//TrainingData//CT_v1"
#IMGS_PATH = path.imgPath()
#MSKS_PATH = path.mskPath()
#OUTPUT_PATH = path.outputPath()

DATA_PATH = "F://MyMasters//Data//TrainingData"
IMGS_PATH = "F://MyMasters//Data//TrainingData//imgs"
MSKS_PATH = "F://MyMasters//Data//TrainingData//masks"
OUTPUT_PATH = "F://MyMasters//Output"

ORIENTATION_ENSEMBLE = ["Axial", "Sagittal", "Coronal"]

print("Image Path: "+"\t"+IMGS_PATH+"\n"+"Mask Path: " +
      "\t"+MSKS_PATH+"\n"+"Output Path: "+"\t"+OUTPUT_PATH)

ScanType = "CT"
n_Scans = 72
Orientation = "Axial"
# Out:
# Image Path: 	F://MyMasters//Data//TrainingData//imgs
# Mask Path: 	F://MyMasters//Data//TrainingData//masks
# Output Path: 	F://MyMasters//Output

# %% [markdown]
# # Import and Process Scans

# %%
# Note to self! Only change ImgDepth in orientaitons other than axial. Otherwise interpolating unnecessarily!!
CT_Images = LoadImages(ScanType=ScanType, ScanClass="Image",
                       ImgPath=IMGS_PATH, n_Scans=n_Scans, ImgSize=256, ImgDepth=256, Orientation=Orientation).LoadScans()
CT_Masks = LoadImages(ScanType=ScanType, ScanClass="Mask",
                      MskPath=MSKS_PATH, n_Scans=n_Scans, ImgSize=256, ImgDepth=256, Orientation=Orientation).LoadScans()

########################## Split Into Train and Test Set ##########################
X, X_Val, y, y_Val = train_test_split(
    CT_Images, CT_Masks, test_size=0.15, random_state=42)

del CT_Images, CT_Masks

y = tf.cast(y, dtype='float32')
y_Val = tf.cast(y_Val, dtype='float32')
# Out:
# Reading the following CT Images:
# CB_001_CT_M0.nii.gz
# CB_003_CT_M0.nii.gz
# CB_004_CT_M0.nii.gz
# CB_005_CT_M0.nii.gz
# CB_007_CT_M0.nii.gz
# CB_009_CT_M0.nii.gz
# CB_013_CT_M0.nii.gz
# CB_020_CT_M1.nii.gz
# CB_021_CT_M6.nii.gz
# CB_022_CT_M0.nii.gz
# CB_027_CT_M0.nii.gz
# CB_029_CT_M0.nii.gz
# CB_030_CT_M0.nii.gz
# CB_034_CT_M0.nii.gz
# CB_034_CT_M1.nii.gz
# CB_034_CT_M6.nii.gz
# CB_035_CT_M0.nii.gz
# CB_035_CT_M1.nii.gz
# CB_035_CT_M6.nii.gz
# CB_041_CT_M0.nii.gz
# CB_041_CT_M1.nii.gz
# CB_041_CT_M3.nii.gz
# CB_042_CT_M0.nii.gz
# CB_042_CT_M1.nii.gz
# CB_042_CT_M6.nii.gz
# CB_043_CT_M0.nii.gz
# CB_043_CT_M1.nii.gz
# CB_043_CT_M6.nii.gz
# CB_077_CT_M1.nii.gz
# CB_087_CT_M0.nii.gz
# CB_087_CT_M1.nii.gz
# CB_087_CT_M6.nii.gz
# CB_088_CT_M0.nii.gz
# CB_088_CT_M1.nii.gz
# CB_088_CT_M6.nii.gz
# CB_089_CT_M0.nii.gz
# CB_089_CT_M1.nii.gz
# CB_089_CT_M6.nii.gz
# CB_090_CT_M0.nii.gz
# CB_090_CT_M1.nii.gz
# CB_090_CT_M6.nii.gz
# CB_092_CT_M0.nii.gz
# CB_092_CT_M1.nii.gz
# CB_092_CT_M18.nii.gz
# CB_092_CT_M6.nii.gz
# CB_093_CT_M0.nii.gz
# CB_095_CT_M0.nii.gz
# CB_095_CT_M1.nii.gz
# CB_095_CT_M6.nii.gz
# CB_098_CT_M0.nii.gz
# CB_098_CT_M1.nii.gz
# CB_098_CT_M6.nii.gz
# CB_099_CT_M0.nii.gz
# CB_099_CT_M1.nii.gz
# CB_099_CT_M18.nii.gz
# CB_099_CT_M6.nii.gz
# CB_100_CT_M1.nii.gz
# CB_100_CT_M18.nii.gz
# CB_100_CT_M6.nii.gz
# CB_101_CT_m0.nii.gz
# CB_101_CT_M1.nii.gz
# CB_101_CT_M6.nii.gz
# CB_102_CT_M0.nii.gz
# CB_102_CT_M1.nii.gz
# CB_102_CT_M6.nii.gz
# CB_103_CT_M18.nii.gz
# CB_104_CT_M0.nii.gz
# CB_104_CT_M1.nii.gz
# CB_104_CT_M6.nii.gz
# CB_105_CT_M0.nii.gz
# CB_105_CT_M1.nii.gz
# CB_105_CT_M6.nii.gz
# Reading the following CT Masks:
# CB_001_lung_all.nii.gz
# CB_003_lung_all.nii.gz
# CB_004_lung_all.nii.gz
# CB_005_lung_all.nii.gz
# CB_007_lung_all.nii.gz
# CB_009_lung_all.nii.gz
# CB_013_lung_all.nii.gz
# CB_020_lung_all.nii.gz
# CB_021_lung_all.nii.gz
# CB_022_lung_all.nii.gz
# CB_027_lungs_all.nii.gz
# CB_029_lung_all.nii.gz
# CB_030_lung_all.nii.gz
# CB_034_lungs_M0.nii.gz
# CB_034_lungs_M1.nii.gz
# CB_034_lungs_M6.nii.gz
# CB_035_lungs_M0.nii.gz
# CB_035_lungs_M1.nii.gz
# CB_035_lungs_M6.nii.gz
# CB_041_lungs_M0.nii.gz
# CB_041_lungs_M1.nii.gz
# CB_041_lungs_M6.nii.gz
# CB_042_lungs_M0.nii.gz
# CB_042_lungs_M1.nii.gz
# CB_042_lungs_M6.nii.gz
# CB_043_lungs_M0.nii.gz
# CB_043_lungs_M1.nii.gz
# CB_043_lungs_M6.nii.gz
# CB_077_lungsLARGE_M1.nii.gz
# CB_087_lungs_M0.nii.gz
# CB_087_lungs_M1.nii.gz
# CB_087_lungs_M6.nii.gz
# CB_088_lungs_M0.nii.gz
# CB_088_lungs_M1.nii.gz
# CB_088_lungs_M6.nii.gz
# CB_089_lungs_M0.nii.gz
# CB_089_lungs_M1.nii.gz
# CB_089_lungs_M6.nii.gz
# CB_090_lungs_M0.nii.gz
# CB_090_lungs_M1.nii.gz
# CB_090_lungs_M6.nii.gz
# CB_092_lungs_M0.nii.gz
# CB_092_lungs_M1.nii.gz
# CB_092_lungs_M18.nii.gz
# CB_092_lungs_M6.nii.gz
# CB_093_lungs_M0.nii.gz
# CB_095_lungs_m0.nii.gz
# CB_095_lungs_M1.nii.gz
# CB_095_lungs_M6.nii.gz
# CB_098_lungs_M0.nii.gz
# CB_098_lungs_M1.nii.gz
# CB_098_lungs_M6.nii.gz
# CB_099_lungsnoheart_M18.nii.gz
# CB_099_lungs_M0.nii.gz
# CB_099_lungs_M1.nii.gz
# CB_099_lungs_M6.nii.gz
# CB_100_lungsnoheart_M18.nii.gz
# CB_100_lungs_M1.nii.gz
# CB_100_lungs_M6.nii.gz
# CB_101_LUNGS_M0.nii.gz
# CB_101_LUNGS_M1.nii.gz
# CB_101_LUNGS_M6.nii.gz
# CB_102_LUNGS_M0.nii.gz
# CB_102_LUNGS_M1.nii.gz
# CB_102_LUNGS_M6.nii.gz
# CB_103_lungs_M18.nii.gz
# CB_104_lungs_M0.nii.gz
# CB_104_lungs_M1.nii.gz
# CB_104_lungs_M6.nii.gz
# CB_105_lungs_M0.nii.gz
# CB_105_lungs_M1.nii.gz
# CB_105_lungs_M6.nii.gz

# %% [markdown]
# ## Expand Arrays with a 4'th Singular Dimension (Grayscale Images)

# %%
X = np.expand_dims(X, axis=3)
y = np.expand_dims(y, axis=3)
X_Val = np.expand_dims(X_Val, axis=3)
y_Val = np.expand_dims(y_Val, axis=3)

# %% [markdown]
# ## Create Data Augmentation Generator

# %%
dataAug = dict(rotation_range=15,
               zoom_range=0.15,
               horizontal_flip=True,
               vertical_flip=True)

image_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**dataAug)
mask_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**dataAug)
seed = 42

image_datagen.fit(X, augment=True, seed=seed)
mask_datagen.fit(y, augment=True, seed=seed)

# %% [markdown]
# ## View Augmented Scans Overlayed with Masks

# %%
X_Aug = image_datagen.flow(X, batch_size=1, seed=seed)
y_Aug = mask_datagen.flow(y, batch_size=1, seed=seed)
viewImages = np.zeros((200, 256, 256, 1))
viewMasks = np.zeros((200, 256, 256, 1))
for i in range(199):
    viewImages[i, :, :, :] = X_Aug.next()[0]
    viewMasks[i, :, :, :] = y_Aug.next()[0]

# %%
showCTMontageOverlay(IMG1=viewImages[0:199, :, :, 0], IMG2=viewMasks[0:199, :, :, 0],
                     SIZE=25, SaveFig=False, save_fig_name="Masks on Images")

# %% [markdown]
# # U-Net

# %% [markdown]
# ## Preparing to Create U-Net

# %%
############## Functions to Log Training of U-Net ##############
def get_run_logdir(root_logdir, input_string):
    import time
    if not input_string:
        run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    else:
        run_id = os.path.join(
            input_string, time.strftime("run_%Y_%m_%d-%H_%M_%S"))
    return os.path.join(root_logdir, run_id)


def create_logdir(modelName):
    root_logdir = os.path.join(os.curdir, "My_logs")
    run_logdir = get_run_logdir(root_logdir, modelName)
    return run_logdir
################################################################

########## Custom Loss Function for Dice Coeffiecient ##########
# https://towardsdatascience.com/dealing-with-class-imbalanced-image-datasets-1cbd17de76b5


def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)


def tversky(y_true, y_pred, smooth=1, alpha=0.7):
    y_true_pos = tf.keras.backend.flatten(y_true)
    y_pred_pos = tf.keras.backend.flatten(y_pred)
    true_pos = tf.keras.backend.sum(y_true_pos * y_pred_pos)
    false_neg = tf.keras.backend.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = tf.keras.backend.sum((1 - y_true_pos) * y_pred_pos)
    return (true_pos + smooth) / (true_pos + alpha * false_neg + (1 - alpha) * false_pos + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=4/3):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)
################################################################

# %% [markdown]
# ## Model Admin..

# %%
MyModelName = 'U-Net_7_3_'+ Orientation
MyLogdir = create_logdir(MyModelName)
MyModelSaveRoot = os.path.join(os.curdir, "TrainedModels")
MyModelSavePath = os.path.join(MyModelSaveRoot, MyModelName+".h5")

print(MyLogdir)
print(MyModelSavePath)
print(MyModelName)
# Out:
# .\My_logs\U-Net_7_3_Axial\run_2020_09_27-10_29_13
# .\TrainedModels\U-Net_7_3_Axial.h5
# U-Net_7_3_Axial

# %% [markdown]
# ## Create UNet

# %%
del MyModel
# importlib.reload(UNet)

# %%
MyModel = UNet.UNet_Adv(input_shape=(256, 256, 1),
                        n_filters=32, activation=tf.keras.layers.LeakyReLU()).CreateUnet()
MyModel.compile(optimizer=Adam(learning_rate=1e-4),
                loss=dice_coef_loss, metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])
MyModel.load_weights(
    "F://MyMasters//Code//Josias-Masters//TrainedModels//U-Net_7_2_Coronal.h5")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 224         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 224         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 32) 224         activation_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 32) 0           batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 32) 0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 32) 224         activation_3[0][0]
# __________________________________________________________________________________________________
# p1 (MaxPooling2D)               (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 2112        p1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 448         activation_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 128, 128, 64) 640         batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 64) 0           depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 64) 448         activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 64) 0           batch_normalization_5[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 64) 448         activation_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 64) 0           depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 64) 448         activation_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 64) 0           batch_normalization_7[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 128, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 64) 448         activation_8[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 64) 0           depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 64) 448         activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           batch_normalization_9[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 64) 448         activation_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 128, 128, 64) 640         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 64) 448         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 64) 0           batch_normalization_11[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 64) 0           batch_normalization_4[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 64) 448         activation_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d (SpatialDropo (None, 128, 128, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# p2 (MaxPooling2D)               (None, 64, 64, 64)   0           spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  8320        p2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 128)  896         activation_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 64, 64, 128)  1280        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 128)  0           depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 128)  896         activation_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           batch_normalization_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 128)  896         activation_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 64, 64, 128)  1280        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 128)  0           depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 128)  896         activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 128)  0           batch_normalization_16[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 128)  0           add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 128)  896         activation_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 64, 64, 128)  1280        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 128)  0           depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 128)  896         activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 128)  0           batch_normalization_18[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 128)  0           add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 128)  896         activation_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 64, 64, 128)  1280        batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 128)  0           depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 128)  896         activation_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 128)  0           batch_normalization_20[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 128)  0           add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 128)  896         activation_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 64, 64, 128)  1280        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 128)  896         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 128)  0           batch_normalization_22[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_16[0][0]
#                                                                  batch_normalization_18[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 128)  0           batch_normalization_13[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 128)  896         activation_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 64, 64, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# p3 (MaxPooling2D)               (None, 32, 32, 128)  0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  33024       p3[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 256)  1792        activation_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 32, 32, 256)  2560        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 256)  1792        activation_23[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 256)  0           batch_normalization_25[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 256)  0           add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 256)  1792        activation_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 256)  1792        activation_25[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 256)  0           batch_normalization_27[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 256)  0           add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 256)  1792        activation_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 256)  1792        activation_27[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 256)  0           batch_normalization_29[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 256)  0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 256)  1792        activation_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 256)  1792        activation_29[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 256)  0           batch_normalization_31[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 256)  0           add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 256)  1792        activation_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 256)  1792        activation_31[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 256)  0           batch_normalization_33[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 256)  1792        activation_32[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 256)  1792        activation_33[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 32, 32, 256)  0           batch_normalization_35[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 256)  1792        activation_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 256)  1792        depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 256)  0           batch_normalization_37[0][0]
#                                                                  batch_normalization_25[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_31[0][0]
#                                                                  batch_normalization_33[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 256)  0           batch_normalization_24[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 256)  0           add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 256)  1792        activation_35[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 32, 32, 256)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# p4 (MaxPooling2D)               (None, 16, 16, 256)  0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 512)  131584      p4[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 16, 16, 512)  3584        activation_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 16, 16, 512)  3584        activation_38[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 16, 512)  0           batch_normalization_41[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 512)  0           add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 512)  3584        activation_39[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 512)  3584        activation_40[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 512)  0           batch_normalization_43[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 512)  0           add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 512)  3584        activation_41[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 16, 512)  3584        activation_42[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 512)  0           batch_normalization_45[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 512)  0           add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 512)  3584        activation_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 512)  3584        activation_44[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 512)  0           batch_normalization_47[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 16, 512)  0           add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 512)  3584        activation_45[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 512)  3584        activation_46[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 512)  0           batch_normalization_49[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 512)  0           add_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 512)  3584        activation_47[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 512)  3584        activation_48[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 16, 16, 512)  0           batch_normalization_51[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 512)  0           add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 512)  3584        activation_49[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 16, 16, 512)  3584        activation_50[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 16, 16, 512)  0           batch_normalization_53[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 512)  0           add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 16, 16, 512)  3584        activation_51[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 16, 16, 512)  3584        activation_52[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 16, 16, 512)  0           batch_normalization_55[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 16, 16, 512)  0           add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 16, 16, 512)  3584        activation_53[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 16, 16, 512)  0           depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 16, 16, 512)  3584        activation_54[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 16, 16, 512)  0           batch_normalization_57[0][0]
#                                                                  batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 16, 16, 512)  0           add_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 16, 16, 512)  3584        activation_55[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 16, 16, 512)  5120        batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 16, 16, 512)  3584        depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 16, 16, 512)  0           batch_normalization_59[0][0]
#                                                                  batch_normalization_41[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_45[0][0]
#                                                                  batch_normalization_47[0][0]
#                                                                  batch_normalization_49[0][0]
#                                                                  batch_normalization_51[0][0]
#                                                                  batch_normalization_53[0][0]
#                                                                  batch_normalization_55[0][0]
#                                                                  batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 16, 512)  0           batch_normalization_39[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 16, 16, 512)  0           add_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 16, 16, 512)  3584        activation_57[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 16, 16, 512)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 512)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  1179904     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 256)  1792        activation_58[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 512)  0           batch_normalization_62[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  131328      concatenate[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 256)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 256)  1792        activation_59[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 256)  1792        activation_60[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 32, 256)  0           batch_normalization_64[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 256)  0           add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 256)  1792        activation_61[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 256)  1792        activation_62[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 32, 256)  0           batch_normalization_66[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 256)  0           add_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 256)  1792        activation_63[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 32, 32, 256)  2560        batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 256)  0           depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 256)  1792        activation_64[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 32, 32, 256)  0           batch_normalization_68[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 256)  0           add_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 256)  1792        activation_65[0][0]
# __________________________________________________________________________________________________
# ...
# activation_78 (Activation)      (None, 64, 64, 128)  0           add_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 64, 64, 128)  896         activation_78[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 64, 64, 128)  0           depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 64, 64, 128)  896         activation_79[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 64, 64, 128)  0           batch_normalization_84[0][0]
#                                                                  batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 64, 64, 128)  0           add_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 64, 64, 128)  896         activation_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 64, 64, 128)  0           depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 64, 64, 128)  896         activation_81[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 64, 64, 128)  0           batch_normalization_86[0][0]
#                                                                  batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 64, 64, 128)  0           add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 64, 64, 128)  896         activation_82[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 64, 64, 128)  1280        batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 64, 64, 128)  896         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 64, 64, 128)  0           batch_normalization_88[0][0]
#                                                                  batch_normalization_80[0][0]
#                                                                  batch_normalization_82[0][0]
#                                                                  batch_normalization_84[0][0]
#                                                                  batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 64, 64, 128)  0           batch_normalization_79[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 64, 64, 128)  0           add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 64, 64, 128)  896         activation_83[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 64, 64, 128)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 64) 73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 128, 128, 64) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 128, 128, 64) 448         activation_84[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 128 0           batch_normalization_90[0][0]
#                                                                  spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 8256        concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 128, 128, 64) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 128, 128, 64) 448         activation_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 128, 128, 64) 0           depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 128, 128, 64) 448         activation_86[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 128, 128, 64) 0           batch_normalization_92[0][0]
#                                                                  batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 128, 128, 64) 0           add_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 128, 128, 64) 448         activation_87[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 128, 128, 64) 0           depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 128, 128, 64) 448         activation_88[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 128, 128, 64) 0           batch_normalization_94[0][0]
#                                                                  batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 128, 128, 64) 0           add_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 128, 128, 64) 448         activation_89[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 128, 128, 64) 0           depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 128, 128, 64) 448         activation_90[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 128, 128, 64) 0           batch_normalization_96[0][0]
#                                                                  batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 128, 128, 64) 0           add_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 128, 128, 64) 448         activation_91[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 128, 128, 64) 640         batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 128, 128, 64) 448         depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 128, 128, 64) 0           batch_normalization_98[0][0]
#                                                                  batch_normalization_92[0][0]
#                                                                  batch_normalization_94[0][0]
#                                                                  batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 128, 128, 64) 0           batch_normalization_91[0][0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 128, 128, 64) 0           add_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 128, 128, 64) 448         activation_92[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 128, 128, 64) 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 32) 18464       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 256, 256, 32) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 256, 256, 32) 224         activation_93[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 64) 0           batch_normalization_100[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 256, 256, 32) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 256, 256, 32) 224         activation_94[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 32) 2080        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 256, 256, 32) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 256, 256, 32) 224         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 256, 256, 32) 224         activation_95[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 256, 256, 32) 0           batch_normalization_102[0][0]
#                                                                  batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 256, 256, 32) 0           add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 256, 256, 32) 224         activation_96[0][0]
# __________________________________________________________________________________________________
# OutLayer (Conv2D)               (None, 256, 256, 1)  33          batch_normalization_104[0][0]
# ==================================================================================================
# Total params: 2,221,089
# Trainable params: 2,105,409
# Non-trainable params: 115,680
# __________________________________________________________________________________________________

# %% [markdown]
# ## Some Callbacks

# %%
csv_logger_cb = tf.keras.callbacks.CSVLogger(
    os.path.join(MyModelSaveRoot, MyModelName+".csv"), append=True)
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(MyModelSavePath,
                                                   monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=15, restore_best_weights=True, monitor='val_loss')
tensorboard_cb = tf.keras.callbacks.TensorBoard(MyLogdir)

# %% [markdown]
# ## Find the Proper Range for the Learning Rate

# %%
print(6e9/8/(256*256*32+1211745))

# %%
batch_size = 8
steps_p_epoch = np.ceil(1000/batch_size)

# Use small subset of data
image_generator = image_datagen.flow(
    X[0:1000, :, :, :], batch_size=batch_size, seed=seed)
mask_generator = mask_datagen.flow(
    y[0:1000, :, :, :], batch_size=batch_size, seed=seed)
train_generator = zip(image_generator, mask_generator)

# %%
lr_finder = LRFinder(min_lr=3e-4, max_lr=2.5e-3,
                     steps_per_epoch=steps_p_epoch, epochs=3)
MyModel.fit(train_generator, steps_per_epoch=steps_p_epoch,
            epochs=3, verbose=1, callbacks=[lr_finder])
lr_finder.plot_loss()

# %%
#learningRates = "0.001-0.006"
# 1st 0.0005-0.006
# 2nd 0.00001-0.0005

base_lr = 3e-4
max_lr = 2.5e-3

clr_triangular_cb = CyclicLR(
    base_lr=base_lr, max_lr=max_lr, mode='triangular2', step_size=5*X.shape[0])

# %% [markdown]
# ### Document Compile Parameters

# %%
#Optimizer = "SGD, Momentum = 0.9, Nestrov = True"
Optimizer = "Adam"
loss = "Dice-Coeff"

# %% [markdown]
# ### Set Training Patameters

# %%
steps_p_epoch = np.ceil(X.shape[0]/batch_size)
image_generator = image_datagen.flow(X, batch_size=batch_size, seed=seed)
mask_generator = mask_datagen.flow(y, batch_size=batch_size, seed=seed)
train_generator = zip(image_generator, mask_generator)
epochs = 20

# %% [markdown]
# ## Train U-Net

# %% [markdown]
# ### Initialise Training

# %%
MyModel.fit(train_generator, steps_per_epoch=steps_p_epoch, epochs=epochs, verbose=1, validation_data=(X_Val, y_Val),
            callbacks=[checkpoint_cb, early_stopping_cb, clr_triangular_cb, tensorboard_cb, csv_logger_cb])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1959.0 steps, validate on 2765 samples
# Epoch 1/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1280 - mean_io_u: 0.8963
# Epoch 00001: val_loss improved from inf to 0.13949, saving model to .\TrainedModels\U-Net_7_3_Axial.h5
# 1959/1959 [==============================] - 1708s 872ms/step - loss: 0.1280 - mean_io_u: 0.8963 - val_loss: 0.1395 - val_mean_io_u: 0.9092
# Epoch 2/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1228 - mean_io_u: 0.8979
# Epoch 00002: val_loss improved from 0.13949 to 0.13381, saving model to .\TrainedModels\U-Net_7_3_Axial.h5
# 1959/1959 [==============================] - 1733s 885ms/step - loss: 0.1227 - mean_io_u: 0.8979 - val_loss: 0.1338 - val_mean_io_u: 0.9091
# Epoch 3/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1242 - mean_io_u: 0.8995
# Epoch 00003: val_loss improved from 0.13381 to 0.13343, saving model to .\TrainedModels\U-Net_7_3_Axial.h5
# 1959/1959 [==============================] - 1594s 814ms/step - loss: 0.1241 - mean_io_u: 0.8995 - val_loss: 0.1334 - val_mean_io_u: 0.9105
# Epoch 4/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1164 - mean_io_u: 0.8998
# Epoch 00004: val_loss did not improve from 0.13343
# 1959/1959 [==============================] - 1706s 871ms/step - loss: 0.1169 - mean_io_u: 0.8998 - val_loss: 0.1339 - val_mean_io_u: 0.9100
# Epoch 5/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1254 - mean_io_u: 0.9002
# Epoch 00005: val_loss improved from 0.13343 to 0.13303, saving model to .\TrainedModels\U-Net_7_3_Axial.h5
# 1959/1959 [==============================] - 1705s 870ms/step - loss: 0.1254 - mean_io_u: 0.9002 - val_loss: 0.1330 - val_mean_io_u: 0.9108
# Epoch 6/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1226 - mean_io_u: 0.9002
# Epoch 00006: val_loss did not improve from 0.13303
# 1959/1959 [==============================] - 1705s 870ms/step - loss: 0.1226 - mean_io_u: 0.9002 - val_loss: 0.1343 - val_mean_io_u: 0.9079
# Epoch 7/20
# 1958/1959 [============================>.] - ETA: 0s - loss: 0.1180 - mean_io_u: 0.9010
# Epoch 00007: val_loss did not improve from 0.13303
# 1959/1959 [==============================] - 1709s 873ms/step - loss: 0.1179 - mean_io_u: 0.9010 - val_loss: 0.1342 - val_mean_io_u: 0.9108
# Epoch 8/20
# 1200/1959 [=================>............] - ETA: 10:46 - loss: 0.1157 - mean_io_u: 0.9005

# %%
clr_triangular_cb._reset()

# %%
MyModel.fit(train_generator, steps_per_epoch=steps_p_epoch, epochs=epochs, verbose=1, validation_data=(X_Val, y_Val),
            callbacks=[checkpoint_cb, early_stopping_cb, clr_triangular_cb, tensorboard_cb, csv_logger_cb])

# %%
MyModel.fit(X, y, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_Val, y_Val),
            callbacks=[checkpoint_cb, early_stopping_cb, clr_triangular_cb, tensorboard_cb, csv_logger_cb])

# %%
clr_triangular_cb._reset()

# %% [markdown]
# ## Load U-Net

# %%
MyModel.load_weights(MyModelSavePath)

# %% [markdown]
# # Write Model Parameters to Text File

# %%
MyModelParameters_Strings = ["ScanType", "n_Scans",
                             "Orientation", "Optimizer", "Loss", "batch_size", "epochs"]
MyModelParameters_values = [ScanType, n_Scans,
                            Orientation, Optimizer, loss, batch_size, 2*epochs]

TextFileName = MyModelName+".txt"
TextFilePath = os.path.join(os.curdir, "TrainedModels", TextFileName)

with open(TextFilePath, "w") as file:
    file.write("Parameters for " + MyModelName + ":\n\n")
    for parameter in enumerate(MyModelParameters_Strings):
        file.write(parameter[1] + ": " +
                   str(MyModelParameters_values[parameter[0]])+"\n")
    file.close()

# %% [markdown]
# # Check Performance on Test Set
# ## View Predicted Images Over Masks

# %%
try:
    y_predict = MyModel.predict(X_Val, batch_size=10, verbose=1)
except:
    X_Val = np.squeeze(X_Val)
    print("Error: Input to Model has to be 4D (x, y, x, 1)")
    print("Reshaping..")
    X_Val = np.expand_dims(X_Val, axis=3)
    y_predict = MyModel.predict(X_Val, batch_size=10, verbose=1)

# %%
y_predict = np.squeeze(y_predict)
X_Val = np.squeeze(X_Val)

try:
    X_Val = np.squeeze(X_Val)
except:
    pass
try:
    y_threshold = np.squeeze(y_threshold)
except:
    pass
try:
    y_Val = np.squeeze(y_Val)
except:
    pass

y_new = np.ma.masked_where(y_predict > 0, y_predict, copy=False)

showCTMontageOverlay(IMG1=X_Val[0:250, :, :],
                     IMG2=y_predict[0:250, :, :], SIZE=25, SaveFig=False, save_fig_name="Predicted Masks on Actual Masks")

# %% [markdown]
# # Check Performance on Test Image

# %%
del LoadImages

# %%
ScanName = "CB_091_CT_M0"
TestImage, Orig_Size, MetaData = LoadImages(ScanType="CT", ScanClass="Image", ScanName=ScanName+".nii.gz",
                                            ImgPath="F:\\MyMasters\\Data\\TestingData\\imgs", Orientation=Orientation).LoadScan()
RunModels(OutPath=OUTPUT_PATH, ScanName="P"+ScanName, Scan=TestImage, Scan_Size=Orig_Size,
          Scan_Metadata=MetaData, Model=MyModel, Orientation=Orientation).runModel()

# %%
Orig_Size
